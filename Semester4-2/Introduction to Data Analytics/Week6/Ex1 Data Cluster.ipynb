# %% [markdown]
# # Data Analytics Book : CODE
#
# **ISBN** : 978-616-338-169-9
#
# **Author** : Rathachai Chawuthai
#
# **Year** : 2022
#
# **Copyright** © by KMITL
#
# **Link** : https://github.com/Rathachai/DA-LAB
#
#
#
# ---

# %% [markdown]
# ## **Chapter 8 : Cluster Analytics**
#
#
# ---

# %% [markdown]
# ### K-Mean

# %%
import pandas as pd

x1 = [54, 61, 22, 20, 16, 34, 75, 78, 33, 26, 60, 64, 79, 82]
x2 = [65, 65, 22, 35, 34, 26, 20, 34, 29, 29, 56, 61, 26, 15]

df = pd.DataFrame({"x1":x1, "x2":x2})
df
# Out:
#     x1  x2
# 0   54  65
# 1   61  65
# 2   22  22
# 3   20  35
# 4   16  34
# 5   34  26
# 6   75  20
# 7   78  34
# 8   33  29
# 9   26  29
# 10  60  56
# 11  64  61
# 12  79  26
# 13  82  15

# %%
df.plot.scatter(x="x1", y="x2")
# Out:
# <AxesSubplot: xlabel='x1', ylabel='x2'>

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(df)

print(kmeans.labels_)
# Out:
# [2 2 0 0 0 0 1 1 0 0 2 2 1 1]
# /Users/phukphoom/miniconda3/envs/DA/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df["clust"] = kmeans.labels_
df
# Out:
#     x1  x2  clust
# 0   54  65      2
# 1   61  65      2
# 2   22  22      0
# 3   20  35      0
# 4   16  34      0
# 5   34  26      0
# 6   75  20      1
# 7   78  34      1
# 8   33  29      0
# 9   26  29      0
# 10  60  56      2
# 11  64  61      2
# 12  79  26      1
# 13  82  15      1

# %%
colors = ["red", "blue", "green"]

df.plot.scatter(x="x1", y="x2", c=df["clust"].astype(int).apply(lambda x: colors[x]))
# Out:
# <AxesSubplot: xlabel='x1', ylabel='x2'>

# %%
_k = []
_sse = []

for k in range(1, 10):
  kmeans = KMeans(n_clusters=k)
  kmeans.fit(df)
  _k.append(k)
  _sse.append(kmeans.inertia_)

sse_df = pd.DataFrame({"k":_k, "sse":_sse})
sse_df.plot(x="k", y="sse")
# Out:
# /Users/phukphoom/miniconda3/envs/DA/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/phukphoom/miniconda3/envs/DA/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/phukphoom/miniconda3/envs/DA/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/phukphoom/miniconda3/envs/DA/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/phukphoom/miniconda3/envs/DA/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/phukphoom/miniconda3/envs/DA/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/phukphoom/miniconda3/envs/DA/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/phukphoom/miniconda3/envs/DA/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/phukphoom/miniconda3/envs/DA/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <AxesSubplot: xlabel='k'>

# %% [markdown]
# ---

# %% [markdown]
# ### DBSCAN

# %%
import pandas as pd

x1 = [54, 61, 22, 20, 16, 34, 75, 78, 33, 26, 60, 64, 79, 82]
x2 = [65, 65, 22, 35, 34, 26, 20, 34, 29, 29, 56, 61, 26, 15]

df = pd.DataFrame({"x1":x1, "x2":x2})
df
# Out:
#     x1  x2
# 0   54  65
# 1   61  65
# 2   22  22
# 3   20  35
# 4   16  34
# 5   34  26
# 6   75  20
# 7   78  34
# 8   33  29
# 9   26  29
# 10  60  56
# 11  64  61
# 12  79  26
# 13  82  15

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN(eps=10, min_samples=3)
dbscan.fit(df)
# Out:
# DBSCAN(eps=10, min_samples=3)

# %%
print(dbscan.labels_)
# Out:
# [0 0 1 1 1 1 2 2 1 1 0 0 2 2]

# %% [markdown]
# ---

# %% [markdown]
# https://rathachai.creatier.pro/
